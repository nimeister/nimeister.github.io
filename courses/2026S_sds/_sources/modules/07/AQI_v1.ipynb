# %%
import pandas as pd
import pdb
import numpy as np
import matplotlib.pyplot as plt

# %%
# read site listing data  - https://aqs.epa.gov/aqsweb/airdata/download_files.html#AQI
sites = pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/aqs_sites.zip')

# %%
print(type(sites))
print(sites.shape)
sites.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (20797, 28)
# Index(['State Code', 'County Code', 'Site Number', 'Latitude', 'Longitude',
#        'Datum', 'Elevation', 'Land Use', 'Location Setting',
#        'Site Established Date', 'Site Closed Date', 'Met Site State Code',
#        'Met Site County Code', 'Met Site Site Number', 'Met Site Type',
#        'Met Site Distance', 'Met Site Direction', 'GMT Offset',
#        'Owning Agency', 'Local Site Name', 'Address', 'Zip Code', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Tribe Name',
#        'Extraction Date'],
#       dtype='object')

# %%
# use bitwise operators
# & for and 
# | for or 
a= sites.loc[sites['State Name'] == 'New York', ['State Code', 'County Code', 'Site Number', 'Location Setting', 'State Name', 'County Name', 'City Name']]
a= sites.loc[(sites['State Name'] == 'New York') & (sites['County Name'] == 'New York'), ['State Code', 'County Code', 'Site Number', 'Location Setting', 'State Name', 'County Name', 'City Name']]
a
# Out:
#       State Code  County Code  Site Number       Location Setting State Name  \
# 12293         36           61            1  URBAN AND CENTER CITY   New York
# 12294         36           61            2  URBAN AND CENTER CITY   New York
# 12295         36           61            5  URBAN AND CENTER CITY   New York
# 12296         36           61           10  URBAN AND CENTER CITY   New York
# 12297         36           61           13  URBAN AND CENTER CITY   New York
# 12298         36           61           14  URBAN AND CENTER CITY   New York
# 12299         36           61           23  URBAN AND CENTER CITY   New York
# 12300         36           61           24  URBAN AND CENTER CITY   New York
# 12301         36           61           37  URBAN AND CENTER CITY   New York
# 12302         36           61           50  URBAN AND CENTER CITY   New York
# 12303         36           61           51  URBAN AND CENTER CITY   New York
# 12304         36           61           53  URBAN AND CENTER CITY   New York
# 12305         36           61           56  URBAN AND CENTER CITY   New York
# 12306         36           61           57  URBAN AND CENTER CITY   New York
# 12307         36           61           58  URBAN AND CENTER CITY   New York
# 12308         36           61           59  URBAN AND CENTER CITY   New York
# 12309         36           61           60  URBAN AND CENTER CITY   New York
# 12310         36           61           61  URBAN AND CENTER CITY   New York
# 12311         36           61           62  URBAN AND CENTER CITY   New York
# 12312         36           61           63  URBAN AND CENTER CITY   New York
# 12313         36           61           65               SUBURBAN   New York
# 12314         36           61           69  URBAN AND CENTER CITY   New York
# 12315         36           61           75               SUBURBAN   New York
# 12316         36           61           77  URBAN AND CENTER CITY   New York
# 12317         36           61           79  URBAN AND CENTER CITY   New York
# 12318         36           61           81  URBAN AND CENTER CITY   New York
# 12319         36           61           82  URBAN AND CENTER CITY   New York
# 12320         36           61           92  URBAN AND CENTER CITY   New York
# 12321         36           61           93  URBAN AND CENTER CITY   New York
# 12322         36           61           95  URBAN AND CENTER CITY   New York
# 12323         36           61          100  URBAN AND CENTER CITY   New York
# 12324         36           61          115  URBAN AND CENTER CITY   New York
# 12325         36           61          117  URBAN AND CENTER CITY   New York
# 12326         36           61          119  URBAN AND CENTER CITY   New York
# 12327         36           61          123  URBAN AND CENTER CITY   New York
# 12328         36           61          125  URBAN AND CENTER CITY   New York
# 12329         36           61          126  URBAN AND CENTER CITY   New York
# 12330         36           61          127  URBAN AND CENTER CITY   New York
# 12331         36           61          128  URBAN AND CENTER CITY   New York
# 12332         36           61          130  URBAN AND CENTER CITY   New York
# 12333         36           61          134  URBAN AND CENTER CITY   New York
# 12334         36           61          135  URBAN AND CENTER CITY   New York
#
#       County Name      City Name
# 12293    New York       New York
# 12294    New York       New York
# 12295    New York       New York
# 12296    New York       New York
# 12297    New York       New York
# 12298    New York       New York
# 12299    New York       New York
# 12300    New York       New York
# 12301    New York       New York
# 12302    New York       New York
# 12303    New York       New York
# 12304    New York       New York
# 12305    New York       New York
# 12306    New York       New York
# 12307    New York       New York
# 12308    New York       New York
# 12309    New York       New York
# 12310    New York       New York
# 12311    New York       New York
# 12312    New York       New York
# 12313    New York       New York
# 12314    New York       New York
# 12315    New York       New York
# 12316    New York       New York
# 12317    New York       New York
# 12318    New York       New York
# 12319    New York       New York
# 12320    New York       New York
# 12321    New York       New York
# 12322    New York       New York
# 12323    New York       New York
# 12324    New York       New York
# 12325    New York       New York
# 12326    New York       New York
# 12327    New York  Not in a city
# 12328    New York       New York
# 12329    New York       New York
# 12330    New York       New York
# 12331    New York       New York
# 12332    New York       New York
# 12333    New York       New York
# 12334    New York       New York

# %%
# use bitwise operators
# & for and 
# | for or 
a= sites.loc[sites['State Name'] == 'New York', ['State Code', 'County Code', 'Site Number', 'Location Setting', 'State Name', 'County Name', 'City Name']]
a= sites.loc[(sites['State Name'] == 'New York') & (sites['County Name'] == 'Queens'), ['State Code', 'County Code', 'Site Number', 'Location Setting', 'State Name', 'County Name', 'City Name']]
a
# Out:
#       State Code  County Code  Site Number       Location Setting State Name  \
# 12462         36           81            4  URBAN AND CENTER CITY   New York
# 12463         36           81            8               SUBURBAN   New York
# 12464         36           81           15               SUBURBAN   New York
# 12465         36           81           16               SUBURBAN   New York
# 12466         36           81           20  URBAN AND CENTER CITY   New York
# 12467         36           81           26  URBAN AND CENTER CITY   New York
# 12468         36           81           29               SUBURBAN   New York
# 12469         36           81           30               SUBURBAN   New York
# 12470         36           81           40  URBAN AND CENTER CITY   New York
# 12471         36           81           41  URBAN AND CENTER CITY   New York
# 12472         36           81           42  URBAN AND CENTER CITY   New York
# 12473         36           81           43  URBAN AND CENTER CITY   New York
# 12474         36           81           44               SUBURBAN   New York
# 12475         36           81           47               SUBURBAN   New York
# 12476         36           81           54  URBAN AND CENTER CITY   New York
# 12477         36           81           70  URBAN AND CENTER CITY   New York
# 12478         36           81           84  URBAN AND CENTER CITY   New York
# 12479         36           81           94  URBAN AND CENTER CITY   New York
# 12480         36           81           96  URBAN AND CENTER CITY   New York
# 12481         36           81           97  URBAN AND CENTER CITY   New York
# 12482         36           81           98  URBAN AND CENTER CITY   New York
# 12483         36           81          116  URBAN AND CENTER CITY   New York
# 12484         36           81          120               SUBURBAN   New York
# 12485         36           81          124  URBAN AND CENTER CITY   New York
# 12486         36           81          125  URBAN AND CENTER CITY   New York
#
#       County Name City Name
# 12462      Queens  New York
# 12463      Queens  New York
# 12464      Queens  New York
# 12465      Queens  New York
# 12466      Queens  New York
# 12467      Queens  New York
# 12468      Queens  New York
# 12469      Queens  New York
# 12470      Queens  New York
# 12471      Queens  New York
# 12472      Queens  New York
# 12473      Queens  New York
# 12474      Queens  New York
# 12475      Queens  New York
# 12476      Queens  New York
# 12477      Queens  New York
# 12478      Queens  New York
# 12479      Queens  New York
# 12480      Queens  New York
# 12481      Queens  New York
# 12482      Queens  New York
# 12483      Queens  New York
# 12484      Queens  New York
# 12485      Queens  New York
# 12486      Queens  New York

# %%
# Site to download air quality data  
# https://aqs.epa.gov/aqsweb/airdata/download_files.html#AQI
#https://aqs.epa.gov/aqsweb/airdata/daily_88101_2021.zip - daily  PM2.5 

pm25_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_88101_2020.zip', parse_dates=['Date Local']) 
O3_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_44201_2020.zip', parse_dates=['Date Local'])
SO2_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42401_2020.zip', parse_dates=['Date Local'])
CO_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42101_2020.zip', parse_dates=['Date Local'])
NO2_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42602_2020.zip', parse_dates=['Date Local'])
# Out:
# C:\Users\Wenge\AppData\Local\Temp\ipykernel_37852\2865157701.py:5: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   pm25_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_88101_2020.zip', parse_dates=['Date Local'])
# C:\Users\Wenge\AppData\Local\Temp\ipykernel_37852\2865157701.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   O3_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_44201_2020.zip')
# C:\Users\Wenge\AppData\Local\Temp\ipykernel_37852\2865157701.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   SO2_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42401_2020.zip')
# C:\Users\Wenge\AppData\Local\Temp\ipykernel_37852\2865157701.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   CO_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42101_2020.zip')
# C:\Users\Wenge\AppData\Local\Temp\ipykernel_37852\2865157701.py:9: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   NO2_daily_2020= pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_42602_2020.zip')

# %%
pm25_daily_2020.shape
# Out:
# (555298, 29)

# %%
pm25_daily_2020.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
O3_daily_2020.shape
# Out:
# (391845, 29)

# %%
SO2_daily_2020.shape
# Out:
# (324817, 29)

# %%
CO_daily_2020.shape
# Out:
# (178789, 29)

# %%
NO2_daily_2020.shape
# Out:
# (157726, 29)

# %%
pm25_daily_2020.head(20)
# Out:
#     State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0            1            3        10           88101    1  30.497478
# 1            1            3        10           88101    1  30.497478
# 2            1            3        10           88101    1  30.497478
# 3            1            3        10           88101    1  30.497478
# 4            1            3        10           88101    1  30.497478
# 5            1            3        10           88101    1  30.497478
# 6            1            3        10           88101    1  30.497478
# 7            1            3        10           88101    1  30.497478
# 8            1            3        10           88101    1  30.497478
# 9            1            3        10           88101    1  30.497478
# 10           1            3        10           88101    1  30.497478
# 11           1            3        10           88101    1  30.497478
# 12           1            3        10           88101    1  30.497478
# 13           1            3        10           88101    1  30.497478
# 14           1            3        10           88101    1  30.497478
# 15           1            3        10           88101    1  30.497478
# 16           1            3        10           88101    1  30.497478
# 17           1            3        10           88101    1  30.497478
# 18           1            3        10           88101    1  30.497478
# 19           1            3        10           88101    1  30.497478
#
#     Longitude  Datum            Parameter Name Sample Duration  ...   AQI  \
# 0  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  48.0
# 1  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  13.0
# 2  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  14.0
# 3  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  39.0
# 4  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  29.0
# 5  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  15.0
# 6  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  10.0
# 7  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  38.0
# 8  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  17.0
# 9  -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  20.0
# 10 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  30.0
# 11 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  16.0
# 12 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  21.0
# 13 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  24.0
# 14 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  31.0
# 15 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  29.0
# 16 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  17.0
# 17 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  15.0
# 18 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  20.0
# 19 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  16.0
#
#    Method Code                                        Method Name  \
# 0        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 1        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 2        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 3        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 4        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 5        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 6        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 7        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 8        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9        145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 10       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 11       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 12       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 13       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 14       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 15       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 16       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 17       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 18       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 19       145.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
#
#       Local Site Name                                            Address  \
# 0   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 1   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 2   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 3   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 4   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 5   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 6   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 7   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 8   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 9   FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 10  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 11  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 12  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 13  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 14  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 15  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 16  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 17  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 18  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 19  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
#
#     State Name  County Name  City Name                  CBSA Name  \
# 0      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 1      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 2      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 3      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 4      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 5      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 6      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 7      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 8      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 9      Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 10     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 11     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 12     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 13     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 14     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 15     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 16     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 17     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 18     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 19     Alabama      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
#
#     Date of Last Change
# 0            2021-10-30
# 1            2021-10-30
# 2            2021-10-30
# 3            2021-10-30
# 4            2021-10-30
# 5            2021-10-30
# 6            2021-10-30
# 7            2021-10-30
# 8            2021-10-30
# 9            2021-10-30
# 10           2021-10-30
# 11           2021-10-30
# 12           2021-10-30
# 13           2021-10-30
# 14           2021-10-30
# 15           2021-10-30
# 16           2021-10-30
# 17           2021-10-30
# 18           2021-10-30
# 19           2021-10-30
#
# [20 rows x 29 columns]

# %%
pm25_daily_2020.sample(10)
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 232723          25            9      5005           88101    3  42.770837
# 71468            6           79      2006           88101    3  35.256510
# 270092          28           35         4           88101    3  31.323890
# 459020          47          157       100           88101    3  35.161260
# 412690          42           45       109           88101    7  39.818715
# 219625          23            9       103           88101    3  44.377050
# 383238          39          153        17           88101    3  41.063526
# 343264          37           35         4           88101    3  35.728889
# 247385          26          161         8           88101    3  42.240565
# 552526          56           35       101           88101    1  42.869824
#
#          Longitude  Datum            Parameter Name Sample Duration  ...  \
# 232723  -71.102290  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 71468  -120.669300  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 270092  -89.292200  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 459020  -89.870650  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 412690  -75.413973  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 219625  -68.260900  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 383238  -81.468956  NAD83  PM2.5 - Local Conditions          1 HOUR  ...
# 343264  -81.365556  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 247385  -83.599602  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 552526 -109.870760  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
#
#          AQI Method Code                                        Method Name  \
# 232723   NaN       170.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 71468   35.0         NaN                                                 -
# 270092   NaN       236.0  Teledyne T640 at 5.0 LPM - Broadband spectroscopy
# 459020   NaN       236.0  Teledyne T640 at 5.0 LPM - Broadband spectroscopy
# 412690  28.0         NaN                                                 -
# 219625  14.0         NaN                                                 -
# 383238   NaN       170.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 343264   NaN       209.0  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# 247385   NaN       183.0  Thermo Scientific 5014i or FH62C14-DHS w/VSCC ...
# 552526   0.0         NaN                                                 -
#
#                                           Local Site Name  \
# 232723                                 CONSENTINO SCHOOL.
# 71468                                     San Luis Obispo
# 270092                                        Hattiesburg
# 459020  Near Road Site at Southwest Tennessee Communit...
# 412690                                        Marcus Hook
# 219625         MCFARLAND HILL Air Pollutant Research Site
# 383238                                            East HS
# 343264                                Hickory Water Tower
# 247385     TOWNER ST, SOUTH; 2 LANE RESIDENIAL - HOSPITAL
# 552526                                   Pinedale Gaseous
#
#                                                   Address      State Name  \
# 232723                              685 WASHINGTON STREET   Massachusetts
# 71468          3220 SOUTH HIGUERA STREET, SAN LUIS OBISPO      California
# 270092                                     205 Bay Street     Mississippi
# 459020                   5767 Macon Cove (Near Road Site)       Tennessee
# 412690                      MARCUS HOOK ELEMENTARY SCHOOL    Pennsylvania
# 219625                                567 Eagle Lake Road           Maine
# 383238                                        80 BRITTAIN            Ohio
# 343264                                    1650 1ST STREET  North Carolina
# 247385                          555 TOWNER ST (YPSILANTI)        Michigan
# 552526  Pinedale Gaseous Monitor on west side of City ...         Wyoming
#
#             County Name        City Name  \
# 232723            Essex        Haverhill
# 71468   San Luis Obispo  San Luis Obispo
# 270092          Forrest      Hattiesburg
# 459020           Shelby          Memphis
# 412690         Delaware      Marcus Hook
# 219625          Hancock    Not in a city
# 383238           Summit            Akron
# 343264          Catawba          Hickory
# 247385        Washtenaw        Ypsilanti
# 552526         Sublette    Not in a city
#
#                                             CBSA Name  Date of Last Change
# 232723                 Boston-Cambridge-Newton, MA-NH           2021-10-31
# 71468   San Luis Obispo-Paso Robles-Arroyo Grande, CA           2021-10-31
# 270092                                Hattiesburg, MS           2021-10-31
# 459020                              Memphis, TN-MS-AR           2022-04-07
# 412690    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD           2021-10-31
# 219625                                            NaN           2022-02-15
# 383238                                      Akron, OH           2021-10-31
# 343264                   Hickory-Lenoir-Morganton, NC           2021-10-31
# 247385                                  Ann Arbor, MI           2021-10-31
# 552526                                            NaN           2022-07-19
#
# [10 rows x 29 columns]

# %%
pm25_daily_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555298 entries, 0 to 555297
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   State Code           555298 non-null  int64
#  1   County Code          555298 non-null  int64
#  2   Site Num             555298 non-null  int64
#  3   Parameter Code       555298 non-null  int64
#  4   POC                  555298 non-null  int64
#  5   Latitude             555298 non-null  float64
#  6   Longitude            555298 non-null  float64
#  7   Datum                555298 non-null  object
#  8   Parameter Name       555298 non-null  object
#  9   Sample Duration      555298 non-null  object
#  10  Pollutant Standard   311778 non-null  object
#  11  Date Local           555298 non-null  datetime64[ns]
#  12  Units of Measure     555298 non-null  object
#  13  Event Type           18311 non-null   object
#  14  Observation Count    555298 non-null  int64
#  15  Observation Percent  555298 non-null  float64
#  16  Arithmetic Mean      555298 non-null  float64
#  17  1st Max Value        555298 non-null  float64
#  18  1st Max Hour         555298 non-null  int64
#  19  AQI                  311778 non-null  float64
#  20  Method Code          315946 non-null  float64
#  21  Method Name          555298 non-null  object
#  22  Local Site Name      539536 non-null  object
#  23  Address              555033 non-null  object
#  24  State Name           555298 non-null  object
#  25  County Name          555298 non-null  object
#  26  City Name            555298 non-null  object
#  27  CBSA Name            511263 non-null  object
#  28  Date of Last Change  555298 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(7), object(14)
# memory usage: 122.9+ MB

# %%
pm25_daily_2020.columns
pm25_daily_2020.index
pm25_daily_2020.values
# Out:
# array([[1, 3, 10, ..., 'Fairhope', 'Daphne-Fairhope-Foley, AL',
#         '2021-10-30'],
#        [1, 3, 10, ..., 'Fairhope', 'Daphne-Fairhope-Foley, AL',
#         '2021-10-30'],
#        [1, 3, 10, ..., 'Fairhope', 'Daphne-Fairhope-Foley, AL',
#         '2021-10-30'],
#        ...,
#        [80, 2, 14, ..., 'Mexicali', nan, '2021-11-01'],
#        [80, 2, 14, ..., 'Mexicali', nan, '2021-11-01'],
#        [80, 2, 14, ..., 'Mexicali', nan, '2021-11-01']], dtype=object)

# %%
pm25_NY = pm25_daily_2020.loc[(pm25_daily_2020['County Name']== 'New York') , ['Site Num', 'Date Local', 'AQI']]
pm25_NY
# Out:
#         Site Num Date Local   AQI
# 339261        79 2020-01-01  10.0
# 339262        79 2020-01-04  50.0
# 339263        79 2020-01-07  34.0
# 339264        79 2020-01-10  25.0
# 339265        79 2020-01-13  33.0
# ...          ...        ...   ...
# 339387       134 2020-02-24  60.0
# 339388       134 2020-02-27  33.0
# 339389       134 2020-03-01  27.0
# 339390       134 2020-03-04  17.0
# 339391       134 2020-03-07  15.0
#
# [131 rows x 3 columns]

# %%
# plot the time series of AQI 
plt.figure(figsize=(15,5), dpi=80)
plt.subplot(1, 1, 1)
plt.plot(pm25_NY['Date Local'], pm25_NY['AQI'])
plt.xticks(rotation = 30, horizontalalignment = 'center')
# Out:
# (array([18262., 18322., 18383., 18444., 18506., 18567., 18628.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18322.0, 0, '2020-03'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18567.0, 0, '2020-11'),
#   Text(18628.0, 0, '2021-01')])

# %%
# extract site numbers, date and AQI 
#pm25_NY = pm25_daily_2020.loc[(pm25_daily_2020['County Name']== 'New York') & (pm25_daily_2020['Site Num']== 79) , ['Site Num', 'Date Local', 'AQI']]
pm25_NY = pm25_daily_2020.loc[ (pm25_daily_2020['County Name']== 'Queens') & (pm25_daily_2020['Site Num']== 124), ['Site Num', 'Date Local', 'AQI']]
pm25_NY[0:100]
# Out:
#         Site Num Date Local   AQI
# 340325       124 2020-01-04  46.0
# 340326       124 2020-01-07  31.0
# 340327       124 2020-01-10  27.0
# 340328       124 2020-01-16  31.0
# 340329       124 2020-01-19  19.0
# ...          ...        ...   ...
# 340420       124 2020-01-03   NaN
# 340421       124 2020-01-04   NaN
# 340422       124 2020-01-05   NaN
# 340423       124 2020-01-06   NaN
# 340424       124 2020-01-07   NaN
#
# [100 rows x 3 columns]

# %%
pm25_NY[150:151]
# Out:
#         Site Num Date Local  AQI
# 339280       124 2020-02-27  NaN

# %%
# plot the time series of AQI 
plt.figure(figsize=(15,5), dpi=80)
plt.subplot(1, 1, 1)
plt.plot(pm25_NY['Date Local'], pm25_NY['AQI'])
#plt.plot(pm25_NY['Date Local'], pm25_NY['AQI'],label='No mask')
#plt.plot(pm25_NY['Date Local'], pm25_NY['AQI'],label='Masked values')
plt.xticks(rotation = 30, horizontalalignment = 'center')
# Out:
# (array([18262., 18322., 18383., 18444., 18506., 18567., 18628.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18322.0, 0, '2020-03'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18567.0, 0, '2020-11'),
#   Text(18628.0, 0, '2021-01')])
