# %% [markdown]
# ### Lab 3 Pandas Series and Dataframe
# - **Author** - Wenge Ni-Meister
# - **Date** - 9/21/2021

# %%
# import necessary Python packages
import pandas as pd

# %%
# import the monthly average precipitation values as a pandas dataframe
TempF = pd.read_csv('http://www.geography.hunter.cuny.edu/~wenge/EDS2023F/data/NYCMet/CPannualT.csv',skiprows=1)
TempF.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %% [markdown]
# ### Question 1 - Find out July maximum temperature

# %%
TempF_July = pd.DataFrame(TempF['JUL'])
TempF_July.max()
# Out:
# JUL    81.3
# dtype: float64

# %% [markdown]
# ## Question 2 -
# - Use two ways to convert the monthly temperature from Fahrenheit to Celsius using the following equation:
# Celsius = (Fahrenheit - 32) / 1.8
# - Print out the Temperature values in Celsius of the for 2006-2015.

# %%
#TempC.iloc[1:21,1:14] = (TempF.iloc[1:21,1:14] - 32)/1.8
TempC = (TempF.iloc[:,1:13] - 32)/1.8
TempC
# Out:
#          JAN       FEB        MAR        APR        MAY        JUN        JUL  \
# 0  -0.388889  2.944444   8.444444  10.555556  17.500000  21.833333  22.388889
# 1   0.888889  2.166667   4.222222  12.333333  17.666667  22.722222  22.888889
# 2   4.388889  4.777778   6.722222  13.388889  15.944444  21.888889  26.000000
# 3  -2.500000 -1.055556   6.166667   9.888889  14.833333  20.166667  24.333333
# 4  -4.055556  1.666667   6.388889  12.000000  18.444444  21.777778  23.611111
# 5  -0.388889  2.500000   4.111111  12.833333  14.944444  23.333333  25.277778
# 6   4.944444  2.055556   6.166667  13.166667  17.277778  21.666667  25.500000
# 7   3.055556 -2.111111   5.666667  10.166667  18.444444  21.888889  23.888889
# 8   2.500000  2.111111   5.888889  12.722222  15.611111  23.333333  25.777778
# 9  -2.277778  2.611111   5.777778  12.500000  16.944444  19.722222  22.611111
# 10  0.277778  0.611111   9.000000  14.388889  18.500000  23.722222  27.388889
# ...

# %%
#TempC = (TempF['Jan':'DEC'] - 32)/1.8
TempC = (TempF.loc[:,'JAN':'DEC'] -32)/1.8

print,TempC
# Out:
# (<function print>,
#           JAN       FEB        MAR        APR        MAY        JUN        JUL  \
#  0  -0.388889  2.944444   8.444444  10.555556  17.500000  21.833333  22.388889
#  1   0.888889  2.166667   4.222222  12.333333  17.666667  22.722222  22.888889
#  2   4.388889  4.777778   6.722222  13.388889  15.944444  21.888889  26.000000
#  3  -2.500000 -1.055556   6.166667   9.888889  14.833333  20.166667  24.333333
#  4  -4.055556  1.666667   6.388889  12.000000  18.444444  21.777778  23.611111
#  5  -0.388889  2.500000   4.111111  12.833333  14.944444  23.333333  25.277778
#  6   4.944444  2.055556   6.166667  13.166667  17.277778  21.666667  25.500000
#  7   3.055556 -2.111111   5.666667  10.166667  18.444444  21.888889  23.888889
#  8   2.500000  2.111111   5.888889  12.722222  15.611111  23.333333  25.777778
#  9  -2.277778  2.611111   5.777778  12.500000  16.944444  19.722222  22.611111
#  10  0.277778  0.611111   9.000000  14.388889  18.500000  23.722222  27.388889
# ...
