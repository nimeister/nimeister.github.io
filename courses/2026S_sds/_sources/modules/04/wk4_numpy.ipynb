# %% [markdown]
# ## HWK 4 -  Numpy

# %%
import numpy as np

# %% [markdown]
# ## Exercise #1 — Array creation & spacing (10 pts)
#
# 1. Create an array `a` using `np.arange` that starts at `-2.5`, ends **before** `3.0`, with a step of `0.5`.
# 2. Create an array `b` using `np.linspace` from `-2.5` to `3.0` (inclusive) with **12** evenly spaced values.
# 3. In **one sentence**, explain why `a` and `b` have different lengths.

# %% [markdown]
# ## Exercise #2 (10 pts)

# %%
a = np.arange(-15, 15).reshape(5,6)**2
a
# Out:
# array([[225, 196, 169, 144, 121, 100],
#        [ 81,  64,  49,  36,  25,  16],
#        [  9,   4,   1,   0,   1,   4],
#        [  9,  16,  25,  36,  49,  64],
#        [ 81, 100, 121, 144, 169, 196]], dtype=int32)

# %% [markdown]
# 1. compute the maximum of each row
# 2. the mean of each column
# 3. The position of the overall minimum

# %% [markdown]
# ## Exerciste #3
# Read NYC monthly temperature data (data/CPAnnualT.csv) into a numpy array, then
# 1. Find out the mean, max, min, and standard deviation of monthly temperature for all 20 years.
# 2. Find out the mean and standard deviation of the monthly temperature for each month.
# 3. Find the years and months when the monthly temperature is greater > 80 degree F
#     and the years and months when the monthly temperature is greater < 32 degree F
# 4. Classify the July temperature into 3 classes:
# Class 1: T < 75F
# Class 2: 75F ≤ D < 80F
# Class 3: T ≥ 80F
