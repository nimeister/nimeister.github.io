# %% [markdown]
# # Homework 2

# %% [markdown]
# ## Exercise 1: Extracting and Formatting Coordinates
#
# - Given a string with the format `"latitude, longitude"` (e.g., `"40.7128N, 74.0060W"`), extract the numeric values of latitude and longitude.
# - Convert these values to floats and remove the directional indicators (`N`, `S`, `E`, `W`).
# - Format the coordinates into a `POINT` WKT string (e.g., `"POINT(-74.0060 40.7128)"`).

# %% [markdown]
# ## Exercise 2: Using For Loops to Process Coordinate Lists
#
# - Create a list of tuples representing coordinates (latitude, longitude).
# - Write a `for` loop that prints each coordinate and indicates whether it is in the Northern or Southern Hemisphere based on the latitude.

# %% [markdown]
# ## Exercise 3: While Loops for Iterative Processing
#
# - Create a list of coordinates (latitude, longitude).
# - Write a `while` loop that continues to print each coordinate until it encounters a coordinate with a negative latitude.
# - Stop the loop once this condition is met.

# %% [markdown]
# ## Exercise 4: Conditional Logic in Loops
#
# - Create a list of coordinates and use a `for` loop to iterate over them.
# - Use an `if-elif-else` statement inside the loop to classify each coordinate based on its longitude:
#   - Print `"Eastern Hemisphere"` if the longitude is greater than 0.
#   - Print `"Western Hemisphere"` if the longitude is less than 0.

# %% [markdown]
# ## Exercise # 5 & 6 - Use function and loop

# %% [markdown]
# Define a function to convert precipitation in mm to inch, then use a loop to convert the 2017 monthly precipitation in mm to inch.
#
# You will use data on average monthly precipitation for 2017 for <a href="https://www.weather.gov/okx/CentralParkHistorical" target="_blank">,provided by the U.S.  National Weather Service. </a>
#
# Month  | Precipitation (inches) |
# --- | --- |
# Jan | 4.83 |
# Feb | 2.48 |
# Mar | 5.25 |
# Apr | 3.84 |
# May | 6.38 |
# June | 4.67 |
# July | 4.19 |
# Aug | 3.34 |
# Sept | 2.00 |
# Oct | 4.18 |
# Nov | 1.58 |
# Dec | 2.21 |

# %% [markdown]
# ## Exercise # 7  - Use a loop to calculate mean and variance of a list of data

# %% [markdown]
# In this exercise, you will use the 2017 NYC precipitation data in Exercise # 3 to calculate the mean value and variance for the list by looping. You are not allowed to use any statistical Python packages
#
# $$
# \mu = \frac{\sum_{i=1}^n x_i}{n}
# $$
#
# $$
# Var(X) = \frac{\sum_{i=1}^n (x_i-\mu)^2}{n}
# $$

# %% [markdown]
# ## Exercise # 8 - create your own sort function using default_valued arguments and arbitary numbers of position or keyward arguments

# %% [markdown]
# ## Exercise # 9 - write a function to calculate the great-circle distance between two points on a sphere given their longitudes and latitudes in miles.

# %% [markdown]
# ## Exercise # 10 -  Write a function called `convert_distance` that converts distances from kilometers to miles and vice versa. The function should accept two parameters: `distance` and `unit`, where `unit` has a default value of `"km"`. If the unit is `"km"`, it should convert the distance to miles, and if the unit is `"miles"`, it should convert the distance to kilometers.
