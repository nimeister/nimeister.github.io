# %% [markdown]
# # Class

# %% [markdown]
# ## Classes
# Classes are blueprints for creating objects, which can have attributes (data) and methods (functions). They help represent more complex data structures.

# %% [markdown]
# The general form for a class definition is simply a collection of attribute definitions, which either take the form of variable assignments or function definitions, resulting in the formation of a new class of object, with its attributes and methods. The syntax for defining a new class of object: specifying its name, attributes, and methods (which are attributes that are functions).

# %%
class RectPrism:
    def __init__(self, length, width, height):
        self.width = width
        self.height = height
        self.length = length
    def volume(self):
        return(self.width*self.height*self.length)
    
PP1 = RectPrism(5,6,7)
PP1.volume()
# Out:
# 210

# %%
class Person:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade
    

emmy = Person('Emmy','senior')
nick = Person('Nick', 'junior')
print(emmy.name)
print(nick.name)
print(emmy.grade)
# Out:
# Emmy
# Nick
# senior

# %%
# a simple Point class to represent geographic points:
class Point:
    def __init__(self, latitude, longitude, name=None):
        self.latitude = latitude
        self.longitude = longitude
        self.name = name

    def __str__(self):
        return f"{self.name or 'Point'} ({self.latitude}, {self.longitude})"


# Example usage
point1 = Point(35.6895, 139.6917, "Tokyo")
print(point1)

# %%
#Exercise
Define a RectPrism to include surface area calculation.
